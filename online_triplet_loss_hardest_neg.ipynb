# %% [markdown]
# ## Mount drive, unzip data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip /content/drive/MyDrive/fingerprint/train_data.zip
# Out:
# Kết quả truyền trực tuyến bị cắt bớt đến 5000 dòng cuối.
#   inflating: train_data/train_set/14_zoom.jpg
#   inflating: train_data/train_set/33_v_shifted.jpg
#   inflating: train_data/train_set/34_h_shifted.jpg
#   inflating: train_data/train_set/46_rotated.jpg
#   inflating: train_data/train_set/58_h_shifted.jpg
#   inflating: train_data/train_set/62_rotated.jpg
#   inflating: train_data/train_set/71_original.jpg
#   inflating: train_data/train_set/100_v_shifted.jpg
#   inflating: train_data/train_set/114_h_shifted.jpg
#   inflating: train_data/train_set/136_noise.jpg
#   inflating: train_data/train_set/139_v_shifted.jpg
#   inflating: train_data/train_set/154_rotated.jpg
#   inflating: train_data/train_set/169_h_shifted.jpg
#   inflating: train_data/train_set/209_noise.jpg
#   inflating: train_data/train_set/232_zoom.jpg
#   inflating: train_data/train_set/257_v_shifted.jpg
#   inflating: train_data/train_set/258_zoom.jpg
#   inflating: train_data/train_set/282_original.jpg
#   inflating: train_data/train_set/286_h_shifted.jpg
#   inflating: train_data/train_set/295_noise.jpg
#   inflating: train_data/train_set/314_original.jpg
#   inflating: train_data/train_set/320_rotated.jpg
#   inflating: train_data/train_set/330_original.jpg
#   inflating: train_data/train_set/356_rotated.jpg
#   inflating: train_data/train_set/361_v_shifted.jpg
#   inflating: train_data/train_set/373_rotated.jpg
#   inflating: train_data/train_set/377_original.jpg
#   inflating: train_data/train_set/384_h_shifted.jpg
#   inflating: train_data/train_set/447_zoom.jpg
#   inflating: train_data/train_set/448_zoom.jpg
#   inflating: train_data/train_set/455_v_shifted.jpg
#   inflating: train_data/train_set/507_original.jpg
#   inflating: train_data/train_set/562_v_shifted.jpg
#   inflating: train_data/train_set/567_noise.jpg
#   inflating: train_data/train_set/595_v_shifted.jpg
#   inflating: train_data/train_set/609_original.jpg
#   inflating: train_data/train_set/626_v_shifted.jpg
#   inflating: train_data/train_set/631_v_shifted.jpg
#   inflating: train_data/train_set/642_original.jpg
#   inflating: train_data/train_set/646_rotated.jpg
#   inflating: train_data/train_set/650_v_shifted.jpg
#   inflating: train_data/train_set/652_noise.jpg
#   inflating: train_data/train_set/658_noise.jpg
#   inflating: train_data/train_set/691_rotated.jpg
#   inflating: train_data/train_set/701_zoom.jpg
#   inflating: train_data/train_set/738_rotated.jpg
#   inflating: train_data/train_set/750_v_shifted.jpg
#   inflating: train_data/train_set/782_noise.jpg
#   inflating: train_data/train_set/825_zoom.jpg
#   inflating: train_data/train_set/836_rotated.jpg
#   inflating: train_data/train_set/848_rotated.jpg
#   inflating: train_data/train_set/858_noise.jpg
#   inflating: train_data/train_set/866_noise.jpg
#   inflating: train_data/train_set/868_h_shifted.jpg
#   inflating: train_data/train_set/884_original.jpg
#   inflating: train_data/train_set/889_h_shifted.jpg
#   inflating: train_data/train_set/939_noise.jpg
#   inflating: train_data/train_set/939_h_shifted.jpg
#   inflating: train_data/train_set/946_zoom.jpg
#   inflating: train_data/train_set/949_rotated.jpg
#   inflating: train_data/train_set/959_h_shifted.jpg
#   inflating: train_data/train_set/969_h_shifted.jpg
#   inflating: train_data/train_set/1050_h_shifted.jpg
#   inflating: train_data/train_set/1050_v_shifted.jpg
#   inflating: train_data/train_set/1067_zoom.jpg
#   inflating: train_data/train_set/1067_noise.jpg
#   inflating: train_data/train_set/1075_zoom.jpg
#   inflating: train_data/train_set/1093_original.jpg
#   inflating: train_data/train_set/1124_h_shifted.jpg
#   inflating: train_data/train_set/1143_zoom.jpg
#   inflating: train_data/train_set/1173_rotated.jpg
#   inflating: train_data/train_set/1174_rotated.jpg
#   inflating: train_data/train_set/1249_original.jpg
#   inflating: train_data/train_set/1271_zoom.jpg
#   inflating: train_data/train_set/1309_h_shifted.jpg
#   inflating: train_data/train_set/1321_v_shifted.jpg
#   inflating: train_data/train_set/1347_rotated.jpg
#   inflating: train_data/train_set/1361_v_shifted.jpg
#   inflating: train_data/train_set/1385_v_shifted.jpg
#   inflating: train_data/train_set/1390_rotated.jpg
#   inflating: train_data/train_set/1391_h_shifted.jpg
#   inflating: train_data/train_set/1406_original.jpg
#   inflating: train_data/train_set/1408_zoom.jpg
#   inflating: train_data/train_set/1427_zoom.jpg
#   inflating: train_data/train_set/1429_zoom.jpg
#   inflating: train_data/train_set/1464_original.jpg
#   inflating: train_data/train_set/1464_rotated.jpg
#   inflating: train_data/train_set/1536_noise.jpg
#   inflating: train_data/train_set/1564_original.jpg
#   inflating: train_data/train_set/1569_original.jpg
#   inflating: train_data/train_set/1628_v_shifted.jpg
#   inflating: train_data/train_set/1637_original.jpg
#   inflating: train_data/train_set/1640_v_shifted.jpg
#   inflating: train_data/train_set/1646_rotated.jpg
#   inflating: train_data/train_set/1659_zoom.jpg
#   inflating: train_data/train_set/1667_rotated.jpg
#   inflating: train_data/train_set/1687_rotated.jpg
#   inflating: train_data/train_set/1714_h_shifted.jpg
#   inflating: train_data/train_set/1729_h_shifted.jpg
#   inflating: train_data/train_set/1734_noise.jpg
#   inflating: train_data/train_set/1748_zoom.jpg
#   inflating: train_data/train_set/1751_noise.jpg
#   inflating: train_data/train_set/1756_noise.jpg
#   inflating: train_data/train_set/1779_original.jpg
#   inflating: train_data/train_set/1812_h_shifted.jpg
#   inflating: train_data/train_set/1824_h_shifted.jpg
#   inflating: train_data/train_set/1838_v_shifted.jpg
#   inflating: train_data/train_set/1872_noise.jpg
#   inflating: train_data/train_set/1901_original.jpg
#   inflating: train_data/train_set/1904_h_shifted.jpg
#   inflating: train_data/train_set/1987_h_shifted.jpg
#   inflating: train_data/train_set/2016_v_shifted.jpg
#   inflating: train_data/train_set/2024_h_shifted.jpg
#   inflating: train_data/train_set/2034_rotated.jpg
#   inflating: train_data/train_set/2039_noise.jpg
#   inflating: train_data/train_set/2079_noise.jpg
#   inflating: train_data/train_set/2093_original.jpg
#   inflating: train_data/train_set/2109_rotated.jpg
#   inflating: train_data/train_set/2123_zoom.jpg
#   inflating: train_data/train_set/2126_zoom.jpg
#   inflating: train_data/train_set/2143_noise.jpg
#   inflating: train_data/train_set/2158_h_shifted.jpg
#   inflating: train_data/train_set/2159_rotated.jpg
#   inflating: train_data/train_set/2167_h_shifted.jpg
#   inflating: train_data/train_set/2168_noise.jpg
#   inflating: train_data/train_set/2181_h_shifted.jpg
#   inflating: train_data/train_set/2182_original.jpg
#   inflating: train_data/train_set/2195_original.jpg
#   inflating: train_data/train_set/2200_noise.jpg
#   inflating: train_data/train_set/2207_zoom.jpg
#   inflating: train_data/train_set/2209_zoom.jpg
#   inflating: train_data/train_set/2210_h_shifted.jpg
#   inflating: train_data/train_set/2220_noise.jpg
#   inflating: train_data/train_set/2221_original.jpg
#   inflating: train_data/train_set/2276_noise.jpg
#   inflating: train_data/train_set/2290_rotated.jpg
#   inflating: train_data/train_set/2301_original.jpg
#   inflating: train_data/train_set/2304_v_shifted.jpg
#   inflating: train_data/train_set/2307_zoom.jpg
#   inflating: train_data/train_set/2323_rotated.jpg
#   inflating: train_data/train_set/2326_original.jpg
#   inflating: train_data/train_set/2345_zoom.jpg
#   inflating: train_data/train_set/2373_zoom.jpg
#   inflating: train_data/train_set/2396_v_shifted.jpg
#   inflating: train_data/train_set/2399_h_shifted.jpg
#   inflating: train_data/train_set/2411_zoom.jpg
#   inflating: train_data/train_set/2412_zoom.jpg
#   inflating: train_data/train_set/2412_rotated.jpg
#   inflating: train_data/train_set/2419_h_shifted.jpg
#   inflating: train_data/train_set/2443_noise.jpg
#   inflating: train_data/train_set/2451_original.jpg
#   inflating: train_data/train_set/2461_zoom.jpg
#   inflating: train_data/train_set/2466_original.jpg
#   inflating: train_data/train_set/2482_rotated.jpg
#   inflating: train_data/train_set/2493_rotated.jpg
#   inflating: train_data/train_set/2527_noise.jpg
#   inflating: train_data/train_set/2686_v_shifted.jpg
#   inflating: train_data/train_set/2708_v_shifted.jpg
#   inflating: train_data/train_set/2732_rotated.jpg
#   inflating: train_data/train_set/2737_rotated.jpg
#   inflating: train_data/train_set/2744_v_shifted.jpg
#   inflating: train_data/train_set/2781_original.jpg
#   inflating: train_data/train_set/2805_zoom.jpg
#   inflating: train_data/train_set/2822_original.jpg
#   inflating: train_data/train_set/2834_zoom.jpg
#   inflating: train_data/train_set/2864_rotated.jpg
#   inflating: train_data/train_set/2870_zoom.jpg
#   inflating: train_data/train_set/2897_rotated.jpg
#   inflating: train_data/train_set/2910_rotated.jpg
#   inflating: train_data/train_set/2926_noise.jpg
#   inflating: train_data/train_set/2950_rotated.jpg
#   inflating: train_data/train_set/2956_original.jpg
#   inflating: train_data/train_set/2956_v_shifted.jpg
#   inflating: train_data/train_set/2960_rotated.jpg
#   inflating: train_data/train_set/2973_h_shifted.jpg
#   inflating: train_data/train_set/2979_rotated.jpg
#   inflating: train_data/train_set/3003_zoom.jpg
#   inflating: train_data/train_set/3007_zoom.jpg
#   inflating: train_data/train_set/3033_noise.jpg
#   inflating: train_data/train_set/3048_noise.jpg
#   inflating: train_data/train_set/3124_noise.jpg
#   inflating: train_data/train_set/3124_h_shifted.jpg
#   inflating: train_data/train_set/3131_rotated.jpg
#   inflating: train_data/train_set/3145_original.jpg
#   inflating: train_data/train_set/3176_zoom.jpg
#   inflating: train_data/train_set/3178_noise.jpg
#   inflating: train_data/train_set/3191_h_shifted.jpg
#   inflating: train_data/train_set/3210_noise.jpg
#   inflating: train_data/train_set/3214_original.jpg
#   inflating: train_data/train_set/3224_zoom.jpg
#   inflating: train_data/train_set/3227_h_shifted.jpg
#   inflating: train_data/train_set/3236_zoom.jpg
#   inflating: train_data/train_set/3238_rotated.jpg
#   inflating: train_data/train_set/3246_h_shifted.jpg
#   inflating: train_data/train_set/3251_zoom.jpg
#   inflating: train_data/train_set/3267_original.jpg
#   inflating: train_data/train_set/3289_rotated.jpg
#   inflating: train_data/train_set/3299_noise.jpg
#   inflating: train_data/train_set/3303_h_shifted.jpg
#   inflating: train_data/train_set/3315_h_shifted.jpg
#   inflating: train_data/train_set/3331_zoom.jpg
#   inflating: train_data/train_set/3351_original.jpg
#   inflating: train_data/train_set/3368_noise.jpg
#   inflating: train_data/train_set/3371_original.jpg
#   inflating: train_data/train_set/3407_zoom.jpg
#   inflating: train_data/train_set/3421_zoom.jpg
#   inflating: train_data/train_set/3429_rotated.jpg
#   inflating: train_data/train_set/3431_noise.jpg
#   inflating: train_data/train_set/3437_h_shifted.jpg
#   inflating: train_data/train_set/3457_original.jpg
#   inflating: train_data/train_set/3492_zoom.jpg
#   inflating: train_data/train_set/3498_original.jpg
#   inflating: train_data/train_set/3498_noise.jpg
#   inflating: train_data/train_set/3500_original.jpg
#   inflating: train_data/train_set/3505_h_shifted.jpg
#   inflating: train_data/train_set/3512_v_shifted.jpg
#   inflating: train_data/train_set/3526_zoom.jpg
#   inflating: train_data/train_set/3527_noise.jpg
#   inflating: train_data/train_set/3540_v_shifted.jpg
#   inflating: train_data/train_set/3546_h_shifted.jpg
#   inflating: train_data/train_set/3553_zoom.jpg
#   inflating: train_data/train_set/3561_v_shifted.jpg
#   inflating: train_data/train_set/3628_original.jpg
#   inflating: train_data/train_set/3630_original.jpg
#   inflating: train_data/train_set/3637_v_shifted.jpg
#   inflating: train_data/train_set/3667_original.jpg
#   inflating: train_data/train_set/3688_noise.jpg
#   inflating: train_data/train_set/3706_v_shifted.jpg
#   inflating: train_data/train_set/3717_noise.jpg
#   inflating: train_data/train_set/3754_original.jpg
#   inflating: train_data/train_set/3757_noise.jpg
#   inflating: train_data/train_set/3777_h_shifted.jpg
#   inflating: train_data/train_set/3794_noise.jpg
#   inflating: train_data/train_set/3794_rotated.jpg
#   inflating: train_data/train_set/3827_original.jpg
#   inflating: train_data/train_set/3889_h_shifted.jpg
#   inflating: train_data/train_set/3924_h_shifted.jpg
#   inflating: train_data/train_set/3936_rotated.jpg
#   inflating: train_data/train_set/3953_noise.jpg
#   inflating: train_data/train_set/3962_rotated.jpg
#   inflating: train_data/train_set/3970_h_shifted.jpg
#   inflating: train_data/train_set/3981_original.jpg
#   inflating: train_data/train_set/3982_noise.jpg
#   inflating: train_data/train_set/4008_zoom.jpg
#   inflating: train_data/train_set/4012_v_shifted.jpg
#   inflating: train_data/train_set/4013_v_shifted.jpg
#   inflating: train_data/train_set/4080_v_shifted.jpg
#   inflating: train_data/train_set/4089_noise.jpg
#   inflating: train_data/train_set/4108_rotated.jpg
#   inflating: train_data/train_set/4120_h_shifted.jpg
#   inflating: train_data/train_set/4160_rotated.jpg
#   inflating: train_data/train_set/4199_h_shifted.jpg
#   inflating: train_data/train_set/4248_original.jpg
#   inflating: train_data/train_set/4275_noise.jpg
#   inflating: train_data/train_set/4298_zoom.jpg
#   inflating: train_data/train_set/4299_h_shifted.jpg
#   inflating: train_data/train_set/4305_noise.jpg
#   inflating: train_data/train_set/4317_original.jpg
#   inflating: train_data/train_set/4322_v_shifted.jpg
#   inflating: train_data/train_set/4326_rotated.jpg
#   inflating: train_data/train_set/4334_v_shifted.jpg
#   inflating: train_data/train_set/4338_original.jpg
#   inflating: train_data/train_set/4370_h_shifted.jpg
#   inflating: train_data/train_set/4377_zoom.jpg
#   inflating: train_data/train_set/4384_noise.jpg
#   inflating: train_data/train_set/4391_h_shifted.jpg
#   inflating: train_data/train_set/4453_zoom.jpg
#   inflating: train_data/train_set/4465_h_shifted.jpg
#   inflating: train_data/train_set/4478_rotated.jpg
#   inflating: train_data/train_set/4508_zoom.jpg
#   inflating: train_data/train_set/4544_h_shifted.jpg
#   inflating: train_data/train_set/4578_original.jpg
#   inflating: train_data/train_set/4581_h_shifted.jpg
#   inflating: train_data/train_set/4599_noise.jpg
#   inflating: train_data/train_set/4600_zoom.jpg
#   inflating: train_data/train_set/4656_rotated.jpg
#   inflating: train_data/train_set/4661_rotated.jpg
#   inflating: train_data/train_set/4674_zoom.jpg
#   inflating: train_data/train_set/4680_noise.jpg
#   inflating: train_data/train_set/4688_zoom.jpg
#   inflating: train_data/train_set/4701_v_shifted.jpg
#   inflating: train_data/train_set/4714_v_shifted.jpg
#   inflating: train_data/train_set/4721_zoom.jpg
#   inflating: train_data/train_set/4721_noise.jpg
#   inflating: train_data/train_set/4730_zoom.jpg
#   inflating: train_data/train_set/4753_h_shifted.jpg
#   inflating: train_data/train_set/4773_zoom.jpg
#   inflating: train_data/train_set/4777_original.jpg
#   inflating: train_data/train_set/4828_h_shifted.jpg
#   inflating: train_data/train_set/4864_zoom.jpg
#   inflating: train_data/train_set/4876_h_shifted.jpg
#   inflating: train_data/train_set/4892_v_shifted.jpg
#   inflating: train_data/train_set/4904_rotated.jpg
#   inflating: train_data/train_set/4917_zoom.jpg
#   inflating: train_data/train_set/4919_noise.jpg
#   inflating: train_data/train_set/4927_original.jpg
#   inflating: train_data/train_set/4948_rotated.jpg
#   inflating: train_data/train_set/4965_noise.jpg
#   inflating: train_data/train_set/4968_h_shifted.jpg
#   inflating: train_data/train_set/4973_noise.jpg
#   inflating: train_data/train_set/4978_v_shifted.jpg
#   inflating: train_data/train_set/4983_original.jpg
#   inflating: train_data/train_set/4984_noise.jpg
#   inflating: train_data/train_set/4993_v_shifted.jpg
#   inflating: train_data/train_set/5002_noise.jpg
#   inflating: train_data/train_set/5013_noise.jpg
#   inflating: train_data/train_set/5037_v_shifted.jpg
#   inflating: train_data/train_set/5047_rotated.jpg
#   inflating: train_data/train_set/5085_v_shifted.jpg
#   inflating: train_data/train_set/5092_rotated.jpg
#   inflating: train_data/train_set/5097_zoom.jpg
#   inflating: train_data/train_set/5098_zoom.jpg
#   inflating: train_data/train_set/5143_zoom.jpg
#   inflating: train_data/train_set/5159_v_shifted.jpg
#   inflating: train_data/train_set/5177_noise.jpg
#   inflating: train_data/train_set/5179_original.jpg
#   inflating: train_data/train_set/5196_original.jpg
#   inflating: train_data/train_set/5198_zoom.jpg
#   inflating: train_data/train_set/5250_rotated.jpg
#   inflating: train_data/train_set/5252_original.jpg
#   inflating: train_data/train_set/5274_original.jpg
#   inflating: train_data/train_set/5277_rotated.jpg
#   inflating: train_data/train_set/5283_original.jpg
#   inflating: train_data/train_set/5296_v_shifted.jpg
#   inflating: train_data/train_set/5325_original.jpg
#   inflating: train_data/train_set/5330_h_shifted.jpg
#   inflating: train_data/train_set/5334_zoom.jpg
#   inflating: train_data/train_set/5376_original.jpg
#   inflating: train_data/train_set/5384_v_shifted.jpg
#   inflating: train_data/train_set/5395_original.jpg
#   inflating: train_data/train_set/5428_v_shifted.jpg
#   inflating: train_data/train_set/5477_original.jpg
#   inflating: train_data/train_set/5485_noise.jpg
#   inflating: train_data/train_set/5489_rotated.jpg
#   inflating: train_data/train_set/5492_original.jpg
#   inflating: train_data/train_set/5496_rotated.jpg
#   inflating: train_data/train_set/5499_v_shifted.jpg
#   inflating: train_data/train_set/5500_h_shifted.jpg
#   inflating: train_data/train_set/5522_noise.jpg
#   inflating: train_data/train_set/5526_h_shifted.jpg
#   inflating: train_data/train_set/5542_h_shifted.jpg
#   inflating: train_data/train_set/5551_rotated.jpg
#   inflating: train_data/train_set/5555_rotated.jpg
#   inflating: train_data/train_set/5572_noise.jpg
#   inflating: train_data/train_set/5583_h_shifted.jpg
#   inflating: train_data/train_set/5606_rotated.jpg
#   inflating: train_data/train_set/5633_h_shifted.jpg
#   inflating: train_data/train_set/5644_original.jpg
#   inflating: train_data/train_set/5652_original.jpg
#   inflating: train_data/train_set/5681_h_shifted.jpg
#   inflating: train_data/train_set/5692_noise.jpg
#   inflating: train_data/train_set/5700_rotated.jpg
#   inflating: train_data/train_set/5713_v_shifted.jpg
#   inflating: train_data/train_set/5715_zoom.jpg
#   inflating: train_data/train_set/5750_original.jpg
#   inflating: train_data/train_set/5752_v_shifted.jpg
#   inflating: train_data/train_set/5778_noise.jpg
#   inflating: train_data/train_set/5838_original.jpg
#   inflating: train_data/train_set/5848_rotated.jpg
#   inflating: train_data/train_set/5891_zoom.jpg
#   inflating: train_data/train_set/5891_rotated.jpg
#   inflating: train_data/train_set/5909_h_shifted.jpg
#   inflating: train_data/train_set/5919_noise.jpg
#   inflating: train_data/train_set/5930_v_shifted.jpg
#   inflating: train_data/train_set/5961_v_shifted.jpg
#   inflating: train_data/train_set/5963_zoom.jpg
#   inflating: train_data/train_set/5965_noise.jpg
#   inflating: train_data/train_set/5970_v_shifted.jpg
#   inflating: train_data/train_set/5977_v_shifted.jpg
#   inflating: train_data/train_set/5986_original.jpg
#   inflating: train_data/train_set/5992_v_shifted.jpg
#   inflating: train_data/train_set/6005_v_shifted.jpg
#   inflating: train_data/train_set/6041_h_shifted.jpg
#   inflating: train_data/train_set/6045_zoom.jpg
#   inflating: train_data/train_set/6048_h_shifted.jpg
#   inflating: train_data/train_set/6074_rotated.jpg
#   inflating: train_data/train_set/6082_v_shifted.jpg
#   inflating: train_data/train_set/6084_h_shifted.jpg
#   inflating: train_data/train_set/6087_zoom.jpg
#   inflating: train_data/train_set/6119_original.jpg
#   inflating: train_data/train_set/6135_v_shifted.jpg
#   inflating: train_data/train_set/6142_rotated.jpg
#   inflating: train_data/train_set/6154_v_shifted.jpg
#   inflating: train_data/train_set/6212_rotated.jpg
#   inflating: train_data/train_set/6214_h_shifted.jpg
#   inflating: train_data/train_set/6231_zoom.jpg
#   inflating: train_data/train_set/6245_rotated.jpg
#   inflating: train_data/train_set/6253_v_shifted.jpg
#   inflating: train_data/train_set/6265_rotated.jpg
#   inflating: train_data/train_set/6278_noise.jpg
#   inflating: train_data/train_set/6301_rotated.jpg
#   inflating: train_data/train_set/6315_noise.jpg
#   inflating: train_data/train_set/6326_h_shifted.jpg
#   inflating: train_data/train_set/6331_rotated.jpg
#   inflating: train_data/train_set/6333_zoom.jpg
#   inflating: train_data/train_set/6333_rotated.jpg
#   inflating: train_data/train_set/6342_zoom.jpg
#   inflating: train_data/train_set/6345_noise.jpg
#   inflating: train_data/train_set/6358_noise.jpg
#   inflating: train_data/train_set/6419_h_shifted.jpg
#   inflating: train_data/train_set/6466_noise.jpg
#   inflating: train_data/train_set/6467_original.jpg
#   inflating: train_data/train_set/6479_v_shifted.jpg
#   inflating: train_data/train_set/6569_v_shifted.jpg
#   inflating: train_data/train_set/6571_zoom.jpg
#   inflating: train_data/train_set/6611_noise.jpg
#   inflating: train_data/train_set/6657_rotated.jpg
#   inflating: train_data/train_set/6676_h_shifted.jpg
#   inflating: train_data/train_set/6684_h_shifted.jpg
#   inflating: train_data/train_set/6696_rotated.jpg
#   inflating: train_data/train_set/6725_v_shifted.jpg
#   inflating: train_data/train_set/6784_original.jpg
#   inflating: train_data/train_set/6849_original.jpg
#   inflating: train_data/train_set/6862_noise.jpg
#   inflating: train_data/train_set/6865_zoom.jpg
#   inflating: train_data/train_set/6915_rotated.jpg
#   inflating: train_data/train_set/6927_v_shifted.jpg
#   inflating: train_data/train_set/6994_v_shifted.jpg
#   inflating: train_data/train_set/7018_h_shifted.jpg
#   inflating: train_data/train_set/7055_h_shifted.jpg
#   inflating: train_data/train_set/7107_v_shifted.jpg
#   inflating: train_data/train_set/7123_noise.jpg
#   inflating: train_data/train_set/7130_original.jpg
#   inflating: train_data/train_set/7138_zoom.jpg
#   inflating: train_data/train_set/7142_v_shifted.jpg
#   inflating: train_data/train_set/7143_original.jpg
#   inflating: train_data/train_set/7161_original.jpg
#   inflating: train_data/train_set/7163_v_shifted.jpg
#   inflating: train_data/train_set/7168_noise.jpg
#   inflating: train_data/train_set/7173_h_shifted.jpg
#   inflating: train_data/train_set/7175_original.jpg
#   inflating: train_data/train_set/7181_h_shifted.jpg
#   inflating: train_data/train_set/7185_v_shifted.jpg
#   inflating: train_data/train_set/7187_noise.jpg
#   inflating: train_data/train_set/7193_h_shifted.jpg
#   inflating: train_data/train_set/7207_noise.jpg
#   inflating: train_data/train_set/7218_rotated.jpg
#   inflating: train_data/train_set/7221_noise.jpg
#   inflating: train_data/train_set/7257_noise.jpg
#   inflating: train_data/train_set/7276_v_shifted.jpg
#   inflating: train_data/train_set/7313_v_shifted.jpg
#   inflating: train_data/train_set/7324_zoom.jpg
#   inflating: train_data/train_set/7342_rotated.jpg
#   inflating: train_data/train_set/7354_original.jpg
#   inflating: train_data/train_set/7376_h_shifted.jpg
#   inflating: train_data/train_set/7379_rotated.jpg
#   inflating: train_data/train_set/7386_noise.jpg
#   inflating: train_data/train_set/7401_v_shifted.jpg
#   inflating: train_data/train_set/7412_original.jpg
#   inflating: train_data/train_set/7412_h_shifted.jpg
#   inflating: train_data/train_set/7412_v_shifted.jpg
#   inflating: train_data/train_set/7418_noise.jpg
#   inflating: train_data/train_set/7459_zoom.jpg
#   inflating: train_data/train_set/7480_v_shifted.jpg
#   inflating: train_data/train_set/7527_noise.jpg
#   inflating: train_data/train_set/7571_zoom.jpg
#   inflating: train_data/train_set/7589_original.jpg
#   inflating: train_data/train_set/7607_zoom.jpg
#   inflating: train_data/train_set/7607_rotated.jpg
#   inflating: train_data/train_set/7614_noise.jpg
#   inflating: train_data/train_set/7640_h_shifted.jpg
#   inflating: train_data/train_set/7657_v_shifted.jpg
#   inflating: train_data/train_set/7666_original.jpg
#   inflating: train_data/train_set/7674_v_shifted.jpg
#   inflating: train_data/train_set/7694_original.jpg
#   inflating: train_data/train_set/7699_v_shifted.jpg
#   inflating: train_data/train_set/7727_h_shifted.jpg
#   inflating: train_data/train_set/7733_noise.jpg
#   inflating: train_data/train_set/7761_v_shifted.jpg
#   inflating: train_data/train_set/7784_rotated.jpg
#   inflating: train_data/train_set/7791_v_shifted.jpg
#   inflating: train_data/train_set/7796_original.jpg
#   inflating: train_data/train_set/7807_rotated.jpg
#   inflating: train_data/train_set/7813_rotated.jpg
#   inflating: train_data/train_set/7819_h_shifted.jpg
#   inflating: train_data/train_set/7848_v_shifted.jpg
#   inflating: train_data/train_set/7851_rotated.jpg
#   inflating: train_data/train_set/7861_v_shifted.jpg
#   inflating: train_data/train_set/7868_zoom.jpg
#   inflating: train_data/train_set/7883_v_shifted.jpg
#   inflating: train_data/train_set/7912_h_shifted.jpg
#   inflating: train_data/train_set/7969_rotated.jpg
#   inflating: train_data/train_set/7979_zoom.jpg
#   inflating: train_data/train_set/7981_zoom.jpg
#   inflating: train_data/train_set/8039_original.jpg
#   inflating: train_data/train_set/8053_v_shifted.jpg
#   inflating: train_data/train_set/8058_h_shifted.jpg
#   inflating: train_data/train_set/8071_v_shifted.jpg
#   inflating: train_data/train_set/8090_v_shifted.jpg
#   inflating: train_data/train_set/8106_noise.jpg
#   inflating: train_data/train_set/8179_rotated.jpg
#   inflating: train_data/train_set/8205_v_shifted.jpg
#   inflating: train_data/train_set/8210_noise.jpg
#   inflating: train_data/train_set/8221_rotated.jpg
#   inflating: train_data/train_set/8226_v_shifted.jpg
#   inflating: train_data/train_set/8237_noise.jpg
#   inflating: train_data/train_set/8239_v_shifted.jpg
#   inflating: train_data/train_set/8241_rotated.jpg
#   inflating: train_data/train_set/8268_zoom.jpg
#   inflating: train_data/train_set/8278_zoom.jpg
#   inflating: train_data/train_set/8299_v_shifted.jpg
#   inflating: train_data/train_set/8318_original.jpg
#   inflating: train_data/train_set/8351_h_shifted.jpg
#   inflating: train_data/train_set/8367_original.jpg
#   inflating: train_data/train_set/8388_noise.jpg
#   inflating: train_data/train_set/8421_zoom.jpg
#   inflating: train_data/train_set/8421_noise.jpg
#   inflating: train_data/train_set/8453_zoom.jpg
#   inflating: train_data/train_set/8460_h_shifted.jpg
#   inflating: train_data/train_set/8469_rotated.jpg
#   inflating: train_data/train_set/8474_rotated.jpg
#   inflating: train_data/train_set/8478_original.jpg
#   inflating: train_data/train_set/8499_zoom.jpg
#   inflating: train_data/train_set/8506_v_shifted.jpg
#   inflating: train_data/train_set/8549_noise.jpg
#   inflating: train_data/train_set/8577_rotated.jpg
#   inflating: train_data/train_set/8601_rotated.jpg
#   inflating: train_data/train_set/8615_rotated.jpg
#   inflating: train_data/train_set/8619_rotated.jpg
#   inflating: train_data/train_set/8664_rotated.jpg
#   inflating: train_data/train_set/8682_v_shifted.jpg
#   inflating: train_data/train_set/8687_v_shifted.jpg
#   inflating: train_data/train_set/8690_v_shifted.jpg
#   inflating: train_data/train_set/8714_zoom.jpg
#   inflating: train_data/train_set/8716_original.jpg
#   inflating: train_data/train_set/8722_original.jpg
#   inflating: train_data/train_set/8729_original.jpg
#   inflating: train_data/train_set/8731_v_shifted.jpg
#   inflating: train_data/train_set/8735_noise.jpg
#   inflating: train_data/train_set/8736_original.jpg
#   inflating: train_data/train_set/8751_rotated.jpg
#   inflating: train_data/train_set/8757_zoom.jpg
#   inflating: train_data/train_set/8780_rotated.jpg
#   inflating: train_data/train_set/8800_v_shifted.jpg
#   inflating: train_data/train_set/8805_original.jpg
#   inflating: train_data/train_set/8815_noise.jpg
#   inflating: train_data/train_set/8871_rotated.jpg
#   inflating: train_data/train_set/8911_zoom.jpg
#   inflating: train_data/train_set/8913_h_shifted.jpg
#   inflating: train_data/train_set/8916_rotated.jpg
#   inflating: train_data/train_set/8925_zoom.jpg
#   inflating: train_data/train_set/8929_noise.jpg
#   inflating: train_data/train_set/8984_noise.jpg
#   inflating: train_data/train_set/9018_original.jpg
#   inflating: train_data/train_set/9029_rotated.jpg
#   inflating: train_data/train_set/9033_original.jpg
#   inflating: train_data/train_set/9037_h_shifted.jpg
#   inflating: train_data/train_set/9114_h_shifted.jpg
#   inflating: train_data/train_set/9124_h_shifted.jpg
#   inflating: train_data/train_set/9142_zoom.jpg
#   inflating: train_data/train_set/9142_rotated.jpg
#   inflating: train_data/train_set/9149_noise.jpg
#   inflating: train_data/train_set/9164_h_shifted.jpg
#   inflating: train_data/train_set/9200_h_shifted.jpg
#   inflating: train_data/train_set/9203_noise.jpg
#   inflating: train_data/train_set/9205_noise.jpg
#   inflating: train_data/train_set/9215_v_shifted.jpg
#   inflating: train_data/train_set/9221_rotated.jpg
#   inflating: train_data/train_set/9222_v_shifted.jpg
#   inflating: train_data/train_set/9228_zoom.jpg
#   inflating: train_data/train_set/9232_noise.jpg
#   inflating: train_data/train_set/9237_rotated.jpg
#   inflating: train_data/train_set/9252_noise.jpg
#   inflating: train_data/train_set/9265_zoom.jpg
#   inflating: train_data/train_set/9286_rotated.jpg
#   inflating: train_data/train_set/9297_rotated.jpg
#   inflating: train_data/train_set/9304_rotated.jpg
#   inflating: train_data/train_set/9321_noise.jpg
#   inflating: train_data/train_set/9346_noise.jpg
#   inflating: train_data/train_set/9350_v_shifted.jpg
#   inflating: train_data/train_set/9376_rotated.jpg
#   inflating: train_data/train_set/9388_h_shifted.jpg
#   inflating: train_data/train_set/9390_h_shifted.jpg
#   inflating: train_data/train_set/9412_noise.jpg
#   inflating: train_data/train_set/9418_v_shifted.jpg
#   inflating: train_data/train_set/9426_h_shifted.jpg
#   inflating: train_data/train_set/9464_zoom.jpg
#   inflating: train_data/train_set/9487_original.jpg
#   inflating: train_data/train_set/9505_original.jpg
#   inflating: train_data/train_set/9531_h_shifted.jpg
#   inflating: train_data/train_set/9540_original.jpg
#   inflating: train_data/train_set/9561_v_shifted.jpg
#   inflating: train_data/train_set/9565_zoom.jpg
#   inflating: train_data/train_set/9567_original.jpg
#   inflating: train_data/train_set/9571_original.jpg
#   inflating: train_data/train_set/9593_noise.jpg
#   inflating: train_data/train_set/9618_zoom.jpg
#   inflating: train_data/train_set/9621_original.jpg
#   inflating: train_data/train_set/9642_zoom.jpg
#   inflating: train_data/train_set/9649_h_shifted.jpg
#   inflating: train_data/train_set/9654_v_shifted.jpg
#   inflating: train_data/train_set/9666_original.jpg
#   inflating: train_data/train_set/9677_h_shifted.jpg
#   inflating: train_data/train_set/9680_original.jpg
#   inflating: train_data/train_set/9693_zoom.jpg
#   inflating: train_data/train_set/9702_zoom.jpg
#   inflating: train_data/train_set/9702_noise.jpg
#   inflating: train_data/train_set/9707_h_shifted.jpg
#   inflating: train_data/train_set/9740_original.jpg
#   inflating: train_data/train_set/9745_original.jpg
#   inflating: train_data/train_set/9784_original.jpg
#   inflating: train_data/train_set/9809_rotated.jpg
#   inflating: train_data/train_set/9817_h_shifted.jpg
#   inflating: train_data/train_set/9857_rotated.jpg
#   inflating: train_data/train_set/9870_v_shifted.jpg
#   inflating: train_data/train_set/9881_original.jpg
#   inflating: train_data/train_set/9884_v_shifted.jpg
#   inflating: train_data/train_set/9887_h_shifted.jpg
#   inflating: train_data/train_set/9891_noise.jpg
#   inflating: train_data/train_set/9905_noise.jpg
#   inflating: train_data/train_set/9942_h_shifted.jpg
#   inflating: train_data/train_set/9960_original.jpg
#   inflating: train_data/train_set/9960_zoom.jpg
#   inflating: train_data/train_set/9978_original.jpg
#   inflating: train_data/train_set/10001_noise.jpg
#   inflating: train_data/train_set/10043_v_shifted.jpg
#   inflating: train_data/train_set/10043_rotated.jpg
#   inflating: train_data/train_set/10068_original.jpg
#   inflating: train_data/train_set/10080_rotated.jpg
#   inflating: train_data/train_set/10149_h_shifted.jpg
#   inflating: train_data/train_set/10154_original.jpg
#   inflating: train_data/train_set/10156_zoom.jpg
#   inflating: train_data/train_set/10157_original.jpg
#   inflating: train_data/train_set/10179_zoom.jpg
#   inflating: train_data/train_set/10185_zoom.jpg
#   inflating: train_data/train_set/10188_zoom.jpg
#   inflating: train_data/train_set/10219_original.jpg
#   inflating: train_data/train_set/10242_h_shifted.jpg
#   inflating: train_data/train_set/10276_h_shifted.jpg
#   inflating: train_data/train_set/10278_zoom.jpg
#   inflating: train_data/train_set/10282_zoom.jpg
#   inflating: train_data/train_set/10284_original.jpg
#   inflating: train_data/train_set/10298_rotated.jpg
#   inflating: train_data/train_set/10301_h_shifted.jpg
#   inflating: train_data/train_set/10311_noise.jpg
#   inflating: train_data/train_set/10316_zoom.jpg
#   inflating: train_data/train_set/10317_original.jpg
#   inflating: train_data/train_set/10332_h_shifted.jpg
#   inflating: train_data/train_set/10334_zoom.jpg
#   inflating: train_data/train_set/10359_rotated.jpg
#   inflating: train_data/train_set/10360_original.jpg
#   inflating: train_data/train_set/10370_zoom.jpg
#   inflating: train_data/train_set/10393_rotated.jpg
#   inflating: train_data/train_set/10401_rotated.jpg
#   inflating: train_data/train_set/10402_v_shifted.jpg
#   inflating: train_data/train_set/10407_v_shifted.jpg
#   inflating: train_data/train_set/10433_v_shifted.jpg
#   inflating: train_data/train_set/10445_zoom.jpg
#   inflating: train_data/train_set/10450_v_shifted.jpg
#   inflating: train_data/train_set/10463_original.jpg
#   inflating: train_data/train_set/10475_noise.jpg
#   inflating: train_data/train_set/10480_rotated.jpg
#   inflating: train_data/train_set/10483_v_shifted.jpg
#   inflating: train_data/train_set/10485_noise.jpg
#   inflating: train_data/train_set/10488_original.jpg
#   inflating: train_data/train_set/10488_h_shifted.jpg
#   inflating: train_data/train_set/10497_h_shifted.jpg
#   inflating: train_data/train_set/10513_v_shifted.jpg
#   inflating: train_data/train_set/10515_h_shifted.jpg
#   inflating: train_data/train_set/10521_h_shifted.jpg
#   inflating: train_data/train_set/10526_h_shifted.jpg
#   inflating: train_data/train_set/10533_v_shifted.jpg
#   inflating: train_data/train_set/10544_noise.jpg
#   inflating: train_data/train_set/10566_h_shifted.jpg
#   inflating: train_data/train_set/10570_zoom.jpg
#   inflating: train_data/train_set/10580_v_shifted.jpg
#   inflating: train_data/train_set/10598_original.jpg
#   inflating: train_data/train_set/10615_zoom.jpg
#   inflating: train_data/train_set/10646_h_shifted.jpg
#   inflating: train_data/train_set/10656_zoom.jpg
#   inflating: train_data/train_set/10680_zoom.jpg
#   inflating: train_data/train_set/10682_noise.jpg
#   inflating: train_data/train_set/10701_noise.jpg
#   inflating: train_data/train_set/10721_noise.jpg
#   inflating: train_data/train_set/10740_v_shifted.jpg
#   inflating: train_data/train_set/10834_rotated.jpg
#   inflating: train_data/train_set/10856_zoom.jpg
#   inflating: train_data/train_set/10860_rotated.jpg
#   inflating: train_data/train_set/10874_v_shifted.jpg
#   inflating: train_data/train_set/10877_noise.jpg
#   inflating: train_data/train_set/10895_v_shifted.jpg
#   inflating: train_data/train_set/10908_v_shifted.jpg
#   inflating: train_data/train_set/10916_original.jpg
#   inflating: train_data/train_set/10919_rotated.jpg
#   inflating: train_data/train_set/10931_v_shifted.jpg
#   inflating: train_data/train_set/10963_noise.jpg
#   inflating: train_data/train_set/11054_h_shifted.jpg
#   inflating: train_data/train_set/11069_rotated.jpg
#   inflating: train_data/train_set/11111_v_shifted.jpg
#   inflating: train_data/train_set/11143_rotated.jpg
#   inflating: train_data/train_set/11191_noise.jpg
#   inflating: train_data/train_set/11197_zoom.jpg
#   inflating: train_data/train_set/11221_v_shifted.jpg
#   inflating: train_data/train_set/11226_h_shifted.jpg
#   inflating: train_data/train_set/11227_h_shifted.jpg
#   inflating: train_data/train_set/11232_original.jpg
#   inflating: train_data/train_set/11255_h_shifted.jpg
#   inflating: train_data/train_set/11262_noise.jpg
#   inflating: train_data/train_set/11274_rotated.jpg
#   inflating: train_data/train_set/11287_zoom.jpg
#   inflating: train_data/train_set/11307_h_shifted.jpg
#   inflating: train_data/train_set/11325_rotated.jpg
#   inflating: train_data/train_set/11342_noise.jpg
#   inflating: train_data/train_set/11344_v_shifted.jpg
#   inflating: train_data/train_set/11353_noise.jpg
#   inflating: train_data/train_set/11376_noise.jpg
#   inflating: train_data/train_set/11392_noise.jpg
#   inflating: train_data/train_set/11393_v_shifted.jpg
#   inflating: train_data/train_set/11398_noise.jpg
#   inflating: train_data/train_set/11420_v_shifted.jpg
#   inflating: train_data/train_set/11423_original.jpg
#   inflating: train_data/train_set/11434_v_shifted.jpg
#   inflating: train_data/train_set/11471_rotated.jpg
#   inflating: train_data/train_set/11472_v_shifted.jpg
#   inflating: train_data/train_set/11477_original.jpg
#   inflating: train_data/train_set/11479_v_shifted.jpg
#   inflating: train_data/train_set/11492_v_shifted.jpg
#   inflating: train_data/train_set/11500_zoom.jpg
#   inflating: train_data/train_set/11514_h_shifted.jpg
#   inflating: train_data/train_set/11517_rotated.jpg
#   inflating: train_data/train_set/11523_v_shifted.jpg
#   inflating: train_data/train_set/11534_original.jpg
#   inflating: train_data/train_set/11534_v_shifted.jpg
#   inflating: train_data/train_set/11581_original.jpg
#   inflating: train_data/train_set/11585_rotated.jpg
#   inflating: train_data/train_set/11586_zoom.jpg
#   inflating: train_data/train_set/11596_v_shifted.jpg
#   inflating: train_data/train_set/11644_h_shifted.jpg
#   inflating: train_data/train_set/11654_zoom.jpg
#   inflating: train_data/train_set/11666_original.jpg
#   inflating: train_data/train_set/11680_original.jpg
#   inflating: train_data/train_set/11718_rotated.jpg
#   inflating: train_data/train_set/11750_rotated.jpg
#   inflating: train_data/train_set/11755_zoom.jpg
#   inflating: train_data/train_set/11788_h_shifted.jpg
#   inflating: train_data/train_set/11793_noise.jpg
#   inflating: train_data/train_set/11812_noise.jpg
#   inflating: train_data/train_set/11813_zoom.jpg
#   inflating: train_data/train_set/11815_original.jpg
#   inflating: train_data/train_set/11839_rotated.jpg
#   inflating: train_data/train_set/11866_noise.jpg
#   inflating: train_data/train_set/11880_zoom.jpg
#   inflating: train_data/train_set/11907_rotated.jpg
#   inflating: train_data/train_set/11917_h_shifted.jpg
#   inflating: train_data/train_set/11928_original.jpg
#   inflating: train_data/train_set/11952_zoom.jpg
#   inflating: train_data/train_set/11959_rotated.jpg
#   inflating: train_data/train_set/11962_rotated.jpg
#   inflating: train_data/train_set/11970_v_shifted.jpg
#   inflating: train_data/train_set/12028_zoom.jpg
#   inflating: train_data/train_set/12039_v_shifted.jpg
#   inflating: train_data/train_set/12045_h_shifted.jpg
#   inflating: train_data/train_set/12071_zoom.jpg
#   inflating: train_data/train_set/12082_noise.jpg
#   inflating: train_data/train_set/12106_h_shifted.jpg
#   inflating: train_data/train_set/12123_original.jpg
#   inflating: train_data/train_set/12130_rotated.jpg
#   inflating: train_data/train_set/12132_noise.jpg
#   inflating: train_data/train_set/12134_h_shifted.jpg
#   inflating: train_data/train_set/12141_zoom.jpg
#   inflating: train_data/train_set/12149_v_shifted.jpg
#   inflating: train_data/train_set/12186_zoom.jpg
#   inflating: train_data/train_set/12192_zoom.jpg
#   inflating: train_data/train_set/12214_noise.jpg
#   inflating: train_data/train_set/12215_rotated.jpg
#   inflating: train_data/train_set/12221_v_shifted.jpg
#   inflating: train_data/train_set/12257_v_shifted.jpg
#   inflating: train_data/train_set/12259_original.jpg
#   inflating: train_data/train_set/12274_noise.jpg
#   inflating: train_data/train_set/12283_original.jpg
#   inflating: train_data/train_set/12286_noise.jpg
#   inflating: train_data/train_set/12292_noise.jpg
#   inflating: train_data/train_set/12328_h_shifted.jpg
#   inflating: train_data/train_set/12338_zoom.jpg
#   inflating: train_data/train_set/12370_original.jpg
#   inflating: train_data/train_set/12373_rotated.jpg
#   inflating: train_data/train_set/12382_rotated.jpg
#   inflating: train_data/train_set/12387_h_shifted.jpg
#   inflating: train_data/train_set/12406_v_shifted.jpg
#   inflating: train_data/train_set/12425_h_shifted.jpg
#   inflating: train_data/train_set/12437_rotated.jpg
#   inflating: train_data/train_set/12471_h_shifted.jpg
#   inflating: train_data/train_set/12480_rotated.jpg
#   inflating: train_data/train_set/12514_rotated.jpg
#   inflating: train_data/train_set/12542_noise.jpg
#   inflating: train_data/train_set/12581_original.jpg
#   inflating: train_data/train_set/12627_zoom.jpg
#   inflating: train_data/train_set/12667_noise.jpg
#   inflating: train_data/train_set/12691_rotated.jpg
#   inflating: train_data/train_set/12718_zoom.jpg
#   inflating: train_data/train_set/12720_original.jpg
#   inflating: train_data/train_set/12753_h_shifted.jpg
#   inflating: train_data/train_set/12766_v_shifted.jpg
#   inflating: train_data/train_set/12789_h_shifted.jpg
#   inflating: train_data/train_set/12795_zoom.jpg
#   inflating: train_data/train_set/12806_v_shifted.jpg
#   inflating: train_data/train_set/12840_v_shifted.jpg
#   inflating: train_data/train_set/12845_rotated.jpg
#   inflating: train_data/train_set/12855_h_shifted.jpg
#   inflating: train_data/train_set/12895_rotated.jpg
#   inflating: train_data/train_set/12924_original.jpg
#   inflating: train_data/train_set/12940_h_shifted.jpg
#   inflating: train_data/train_set/12964_h_shifted.jpg
#   inflating: train_data/train_set/12984_noise.jpg
#   inflating: train_data/train_set/12994_h_shifted.jpg
#   inflating: train_data/train_set/13009_noise.jpg
#   inflating: train_data/train_set/13036_zoom.jpg
#   inflating: train_data/train_set/13044_original.jpg
#   inflating: train_data/train_set/13050_original.jpg
#   inflating: train_data/train_set/13074_zoom.jpg
#   inflating: train_data/train_set/13076_v_shifted.jpg
#   inflating: train_data/train_set/13091_noise.jpg
#   inflating: train_data/train_set/13095_zoom.jpg
#   inflating: train_data/train_set/13115_zoom.jpg
#   inflating: train_data/train_set/13125_rotated.jpg
#   inflating: train_data/train_set/13164_v_shifted.jpg
#   inflating: train_data/train_set/13169_noise.jpg
#   inflating: train_data/train_set/13174_rotated.jpg
#   inflating: train_data/train_set/13216_rotated.jpg
#   inflating: train_data/train_set/13237_v_shifted.jpg
#   inflating: train_data/train_set/13244_rotated.jpg
#   inflating: train_data/train_set/13268_original.jpg
#   inflating: train_data/train_set/13270_v_shifted.jpg
#   inflating: train_data/train_set/13285_original.jpg
#   inflating: train_data/train_set/13307_original.jpg
#   inflating: train_data/train_set/13346_noise.jpg
#   inflating: train_data/train_set/13351_v_shifted.jpg
#   inflating: train_data/train_set/13360_noise.jpg
#   inflating: train_data/train_set/13363_noise.jpg
#   inflating: train_data/train_set/13363_v_shifted.jpg
#   inflating: train_data/train_set/13397_zoom.jpg
#   inflating: train_data/train_set/13407_v_shifted.jpg
#   inflating: train_data/train_set/13414_noise.jpg
#   inflating: train_data/train_set/13440_h_shifted.jpg
#   inflating: train_data/train_set/13455_original.jpg
#   inflating: train_data/train_set/13468_rotated.jpg
#   inflating: train_data/train_set/13472_noise.jpg
#   inflating: train_data/train_set/13474_h_shifted.jpg
#   inflating: train_data/train_set/13478_zoom.jpg
#   inflating: train_data/train_set/13483_v_shifted.jpg
#   inflating: train_data/train_set/13495_noise.jpg
#   inflating: train_data/train_set/13505_h_shifted.jpg
#   inflating: train_data/train_set/13545_original.jpg
#   inflating: train_data/train_set/13564_v_shifted.jpg
#   inflating: train_data/train_set/13566_original.jpg
#   inflating: train_data/train_set/13594_original.jpg
#   inflating: train_data/train_set/13600_zoom.jpg
#   inflating: train_data/train_set/13631_zoom.jpg
#   inflating: train_data/train_set/13631_noise.jpg
#   inflating: train_data/train_set/13635_noise.jpg
#   inflating: train_data/train_set/13666_noise.jpg
#   inflating: train_data/train_set/13675_v_shifted.jpg
#   inflating: train_data/train_set/13717_original.jpg
#   inflating: train_data/train_set/13718_h_shifted.jpg
#   inflating: train_data/train_set/13749_rotated.jpg
#   inflating: train_data/train_set/13750_noise.jpg
#   inflating: train_data/train_set/13752_original.jpg
#   inflating: train_data/train_set/13775_h_shifted.jpg
#   inflating: train_data/train_set/13815_zoom.jpg
#   inflating: train_data/train_set/13831_zoom.jpg
#   inflating: train_data/train_set/13840_rotated.jpg
#   inflating: train_data/train_set/13845_rotated.jpg
#   inflating: train_data/train_set/13852_rotated.jpg
#   inflating: train_data/train_set/13853_zoom.jpg
#   inflating: train_data/train_set/13856_h_shifted.jpg
#   inflating: train_data/train_set/13856_v_shifted.jpg
#   inflating: train_data/train_set/13857_h_shifted.jpg
#   inflating: train_data/train_set/13923_rotated.jpg
#   inflating: train_data/train_set/13932_h_shifted.jpg
#   inflating: train_data/train_set/13934_zoom.jpg
#   inflating: train_data/train_set/14056_original.jpg
#   inflating: train_data/train_set/14077_h_shifted.jpg
#   inflating: train_data/train_set/14086_zoom.jpg
#   inflating: train_data/train_set/14116_h_shifted.jpg
#   inflating: train_data/train_set/14143_zoom.jpg
#   inflating: train_data/train_set/14173_zoom.jpg
#   inflating: train_data/train_set/14179_zoom.jpg
#   inflating: train_data/train_set/14196_h_shifted.jpg
#   inflating: train_data/train_set/14242_noise.jpg
#   inflating: train_data/train_set/14242_rotated.jpg
#   inflating: train_data/train_set/14267_zoom.jpg
#   inflating: train_data/train_set/14290_rotated.jpg
#   inflating: train_data/train_set/14346_h_shifted.jpg
#   inflating: train_data/train_set/14360_v_shifted.jpg
#   inflating: train_data/train_set/14365_h_shifted.jpg
#   inflating: train_data/train_set/14368_noise.jpg
#   inflating: train_data/train_set/14373_v_shifted.jpg
#   inflating: train_data/train_set/14375_original.jpg
#   inflating: train_data/train_set/14390_rotated.jpg
#   inflating: train_data/train_set/14407_h_shifted.jpg
#   inflating: train_data/train_set/14409_h_shifted.jpg
#   inflating: train_data/train_set/14416_noise.jpg
#   inflating: train_data/train_set/14435_original.jpg
#   inflating: train_data/train_set/14456_zoom.jpg
#   inflating: train_data/train_set/14457_noise.jpg
#   inflating: train_data/train_set/14468_rotated.jpg
#   inflating: train_data/train_set/14471_original.jpg
#   inflating: train_data/train_set/14478_zoom.jpg
#   inflating: train_data/train_set/14484_v_shifted.jpg
#   inflating: train_data/train_set/14485_h_shifted.jpg
# ...
#   inflating: train_data/train_set/11429_zoom.jpg
#   inflating: train_data/train_set/11432_zoom.jpg
#   inflating: train_data/train_set/11451_h_shifted.jpg
#   inflating: train_data/train_set/11516_zoom.jpg
#   inflating: train_data/train_set/11528_zoom.jpg
#   inflating: train_data/train_set/11555_original.jpg
#   inflating: train_data/train_set/11556_v_shifted.jpg
#   inflating: train_data/train_set/11575_h_shifted.jpg
#   inflating: train_data/train_set/11589_v_shifted.jpg
#   inflating: train_data/train_set/11637_v_shifted.jpg
#   inflating: train_data/train_set/11648_v_shifted.jpg
#   inflating: train_data/train_set/11680_v_shifted.jpg
#   inflating: train_data/train_set/11692_noise.jpg
#   inflating: train_data/train_set/11702_rotated.jpg
#   inflating: train_data/train_set/11716_original.jpg
#   inflating: train_data/train_set/11716_noise.jpg
#   inflating: train_data/train_set/11719_rotated.jpg
#   inflating: train_data/train_set/11725_noise.jpg
#   inflating: train_data/train_set/11746_original.jpg
#   inflating: train_data/train_set/11755_v_shifted.jpg
#   inflating: train_data/train_set/11761_zoom.jpg
#   inflating: train_data/train_set/11824_h_shifted.jpg
#   inflating: train_data/train_set/11836_v_shifted.jpg
#   inflating: train_data/train_set/11850_v_shifted.jpg
#   inflating: train_data/train_set/11857_original.jpg
#   inflating: train_data/train_set/11861_zoom.jpg
#   inflating: train_data/train_set/11869_original.jpg
#   inflating: train_data/train_set/11879_noise.jpg
#   inflating: train_data/train_set/11880_rotated.jpg
#   inflating: train_data/train_set/11893_v_shifted.jpg
#   inflating: train_data/train_set/11914_rotated.jpg
#   inflating: train_data/train_set/11923_zoom.jpg
#   inflating: train_data/train_set/11947_zoom.jpg
#   inflating: train_data/train_set/11952_v_shifted.jpg
#   inflating: train_data/train_set/11971_noise.jpg
#   inflating: train_data/train_set/11997_rotated.jpg
#   inflating: train_data/train_set/11998_zoom.jpg
#   inflating: train_data/train_set/11998_v_shifted.jpg
#   inflating: train_data/train_set/12026_v_shifted.jpg
#   inflating: train_data/train_set/12033_original.jpg
#   inflating: train_data/train_set/12039_noise.jpg
#   inflating: train_data/train_set/12050_zoom.jpg
#   inflating: train_data/train_set/12084_v_shifted.jpg
#   inflating: train_data/train_set/12111_original.jpg
#   inflating: train_data/train_set/12118_v_shifted.jpg
#   inflating: train_data/train_set/12130_h_shifted.jpg
#   inflating: train_data/train_set/12154_v_shifted.jpg
#   inflating: train_data/train_set/12162_original.jpg
#   inflating: train_data/train_set/12174_original.jpg
#   inflating: train_data/train_set/12176_original.jpg
#   inflating: train_data/train_set/12198_rotated.jpg
#   inflating: train_data/train_set/12212_original.jpg
#   inflating: train_data/train_set/12250_h_shifted.jpg
#   inflating: train_data/train_set/12278_noise.jpg
#   inflating: train_data/train_set/12357_h_shifted.jpg
#   inflating: train_data/train_set/12358_h_shifted.jpg
#   inflating: train_data/train_set/12363_noise.jpg
#   inflating: train_data/train_set/12395_original.jpg
#   inflating: train_data/train_set/12402_rotated.jpg
#   inflating: train_data/train_set/12413_rotated.jpg
#   inflating: train_data/train_set/12427_original.jpg
#   inflating: train_data/train_set/12444_zoom.jpg
#   inflating: train_data/train_set/12447_rotated.jpg
#   inflating: train_data/train_set/12490_zoom.jpg
#   inflating: train_data/train_set/12495_noise.jpg
#   inflating: train_data/train_set/12505_v_shifted.jpg
#   inflating: train_data/train_set/12518_noise.jpg
#   inflating: train_data/train_set/12568_original.jpg
#   inflating: train_data/train_set/12578_h_shifted.jpg
#   inflating: train_data/train_set/12580_zoom.jpg
#   inflating: train_data/train_set/12583_zoom.jpg
#   inflating: train_data/train_set/12584_rotated.jpg
#   inflating: train_data/train_set/12601_zoom.jpg
#   inflating: train_data/train_set/12635_v_shifted.jpg
#   inflating: train_data/train_set/12637_h_shifted.jpg
#   inflating: train_data/train_set/12640_original.jpg
#   inflating: train_data/train_set/12669_v_shifted.jpg
#   inflating: train_data/train_set/12677_rotated.jpg
#   inflating: train_data/train_set/12702_v_shifted.jpg
#   inflating: train_data/train_set/12734_rotated.jpg
#   inflating: train_data/train_set/12739_zoom.jpg
#   inflating: train_data/train_set/12775_h_shifted.jpg
#   inflating: train_data/train_set/12821_h_shifted.jpg
#   inflating: train_data/train_set/12833_h_shifted.jpg
#   inflating: train_data/train_set/12863_zoom.jpg
#   inflating: train_data/train_set/12872_noise.jpg
#   inflating: train_data/train_set/12919_original.jpg
#   inflating: train_data/train_set/12921_noise.jpg
#   inflating: train_data/train_set/12959_h_shifted.jpg
#   inflating: train_data/train_set/12965_zoom.jpg
#   inflating: train_data/train_set/12966_v_shifted.jpg
#   inflating: train_data/train_set/13001_noise.jpg
#   inflating: train_data/train_set/13008_noise.jpg
#   inflating: train_data/train_set/13023_noise.jpg
#   inflating: train_data/train_set/13033_zoom.jpg
#   inflating: train_data/train_set/13034_original.jpg
#   inflating: train_data/train_set/13070_v_shifted.jpg
#   inflating: train_data/train_set/13082_h_shifted.jpg
#   inflating: train_data/train_set/13100_original.jpg
#   inflating: train_data/train_set/13101_h_shifted.jpg
#   inflating: train_data/train_set/13134_zoom.jpg
#   inflating: train_data/train_set/13163_original.jpg
#   inflating: train_data/train_set/13168_noise.jpg
#   inflating: train_data/train_set/13178_v_shifted.jpg
#   inflating: train_data/train_set/13203_v_shifted.jpg
#   inflating: train_data/train_set/13220_zoom.jpg
#   inflating: train_data/train_set/13228_rotated.jpg
#   inflating: train_data/train_set/13229_original.jpg
#   inflating: train_data/train_set/13255_rotated.jpg
#   inflating: train_data/train_set/13290_original.jpg
#   inflating: train_data/train_set/13315_original.jpg
#   inflating: train_data/train_set/13371_noise.jpg
#   inflating: train_data/train_set/13382_zoom.jpg
#   inflating: train_data/train_set/13394_h_shifted.jpg
#   inflating: train_data/train_set/13433_h_shifted.jpg
#   inflating: train_data/train_set/13436_zoom.jpg
#   inflating: train_data/train_set/13456_rotated.jpg
#   inflating: train_data/train_set/13462_noise.jpg
#   inflating: train_data/train_set/13473_original.jpg
#   inflating: train_data/train_set/13499_rotated.jpg
#   inflating: train_data/train_set/13500_zoom.jpg
#   inflating: train_data/train_set/13518_original.jpg
#   inflating: train_data/train_set/13545_noise.jpg
#   inflating: train_data/train_set/13545_v_shifted.jpg
#   inflating: train_data/train_set/13576_original.jpg
#   inflating: train_data/train_set/13595_v_shifted.jpg
#   inflating: train_data/train_set/13597_rotated.jpg
#   inflating: train_data/train_set/13606_v_shifted.jpg
#   inflating: train_data/train_set/13616_noise.jpg
#   inflating: train_data/train_set/13625_h_shifted.jpg
#   inflating: train_data/train_set/13629_h_shifted.jpg
#   inflating: train_data/train_set/13635_v_shifted.jpg
#   inflating: train_data/train_set/13638_zoom.jpg
#   inflating: train_data/train_set/13653_original.jpg
#   inflating: train_data/train_set/13662_v_shifted.jpg
#   inflating: train_data/train_set/13680_zoom.jpg
#   inflating: train_data/train_set/13680_h_shifted.jpg
#   inflating: train_data/train_set/13690_noise.jpg
#   inflating: train_data/train_set/13692_rotated.jpg
#   inflating: train_data/train_set/13721_original.jpg
#   inflating: train_data/train_set/13725_v_shifted.jpg
#   inflating: train_data/train_set/13733_h_shifted.jpg
#   inflating: train_data/train_set/13742_v_shifted.jpg
#   inflating: train_data/train_set/13746_noise.jpg
#   inflating: train_data/train_set/13760_h_shifted.jpg
#   inflating: train_data/train_set/13770_v_shifted.jpg
#   inflating: train_data/train_set/13800_rotated.jpg
#   inflating: train_data/train_set/13814_zoom.jpg
#   inflating: train_data/train_set/13834_h_shifted.jpg
#   inflating: train_data/train_set/13850_noise.jpg
#   inflating: train_data/train_set/13855_v_shifted.jpg
#   inflating: train_data/train_set/13863_zoom.jpg
#   inflating: train_data/train_set/13885_h_shifted.jpg
#   inflating: train_data/train_set/13894_h_shifted.jpg
#   inflating: train_data/train_set/13914_zoom.jpg
#   inflating: train_data/train_set/13915_noise.jpg
#   inflating: train_data/train_set/13920_noise.jpg
#   inflating: train_data/train_set/13972_rotated.jpg
#   inflating: train_data/train_set/13981_v_shifted.jpg
#   inflating: train_data/train_set/13991_v_shifted.jpg
#   inflating: train_data/train_set/13996_noise.jpg
#   inflating: train_data/train_set/13997_noise.jpg
#   inflating: train_data/train_set/14002_noise.jpg
#   inflating: train_data/train_set/14011_noise.jpg
#   inflating: train_data/train_set/14024_original.jpg
#   inflating: train_data/train_set/14027_rotated.jpg
#   inflating: train_data/train_set/14040_noise.jpg
#   inflating: train_data/train_set/14044_h_shifted.jpg
#   inflating: train_data/train_set/14060_zoom.jpg
#   inflating: train_data/train_set/14074_v_shifted.jpg
#   inflating: train_data/train_set/14095_rotated.jpg
#   inflating: train_data/train_set/14113_original.jpg
#   inflating: train_data/train_set/14142_rotated.jpg
#   inflating: train_data/train_set/14149_zoom.jpg
#   inflating: train_data/train_set/14168_v_shifted.jpg
#   inflating: train_data/train_set/14179_noise.jpg
#   inflating: train_data/train_set/14194_zoom.jpg
#   inflating: train_data/train_set/14206_h_shifted.jpg
#   inflating: train_data/train_set/14215_noise.jpg
#   inflating: train_data/train_set/14216_rotated.jpg
#   inflating: train_data/train_set/14238_rotated.jpg
#   inflating: train_data/train_set/14278_original.jpg
#   inflating: train_data/train_set/14294_noise.jpg
#   inflating: train_data/train_set/14299_original.jpg
#   inflating: train_data/train_set/14304_rotated.jpg
#   inflating: train_data/train_set/14329_h_shifted.jpg
#   inflating: train_data/train_set/14331_h_shifted.jpg
#   inflating: train_data/train_set/14337_original.jpg
#   inflating: train_data/train_set/14342_h_shifted.jpg
#   inflating: train_data/train_set/14357_rotated.jpg
#   inflating: train_data/train_set/14381_v_shifted.jpg
#   inflating: train_data/train_set/14385_zoom.jpg
#   inflating: train_data/train_set/14385_h_shifted.jpg
#   inflating: train_data/train_set/14416_h_shifted.jpg
#   inflating: train_data/train_set/14444_noise.jpg
#   inflating: train_data/train_set/14448_original.jpg
#   inflating: train_data/train_set/14449_rotated.jpg
#   inflating: train_data/train_set/14456_h_shifted.jpg
#   inflating: train_data/train_set/14473_v_shifted.jpg
#   inflating: train_data/train_set/14522_noise.jpg
#   inflating: train_data/train_set/14531_rotated.jpg
#   inflating: train_data/train_set/14541_noise.jpg
#   inflating: train_data/train_set/14550_rotated.jpg
#   inflating: train_data/train_set/14593_v_shifted.jpg
#   inflating: train_data/train_set/14630_v_shifted.jpg
#   inflating: train_data/train_set/14673_v_shifted.jpg
#   inflating: train_data/train_set/14691_v_shifted.jpg
#   inflating: train_data/train_set/14702_rotated.jpg
#   inflating: train_data/train_set/14712_noise.jpg
#   inflating: train_data/train_set/14718_v_shifted.jpg
#   inflating: train_data/train_set/14738_original.jpg
#   inflating: train_data/train_set/14783_v_shifted.jpg
#   inflating: train_data/train_set/14796_zoom.jpg
#   inflating: train_data/train_set/14804_rotated.jpg
#   inflating: train_data/train_set/14843_noise.jpg
#   inflating: train_data/train_set/14853_h_shifted.jpg
#   inflating: train_data/train_set/14853_v_shifted.jpg
#   inflating: train_data/train_set/14866_h_shifted.jpg
#   inflating: train_data/train_set/14886_h_shifted.jpg
#   inflating: train_data/train_set/14933_v_shifted.jpg
#   inflating: train_data/train_set/14947_original.jpg
#   inflating: train_data/train_set/14950_h_shifted.jpg
#   inflating: train_data/train_set/14968_rotated.jpg
#   inflating: train_data/train_set/14974_v_shifted.jpg
#   inflating: train_data/train_set/14998_v_shifted.jpg
#   inflating: train_data/train_set/15002_original.jpg
#   inflating: train_data/train_set/15007_v_shifted.jpg
#   inflating: train_data/train_set/15013_original.jpg
#   inflating: train_data/train_set/15016_rotated.jpg
#   inflating: train_data/train_set/15023_noise.jpg
#   inflating: train_data/train_set/15061_original.jpg
#   inflating: train_data/train_set/15063_h_shifted.jpg
#   inflating: train_data/train_set/15064_zoom.jpg
#   inflating: train_data/train_set/15068_zoom.jpg
#   inflating: train_data/train_set/15068_h_shifted.jpg
#   inflating: train_data/train_set/15072_v_shifted.jpg
#   inflating: train_data/train_set/15075_h_shifted.jpg
#   inflating: train_data/train_set/15105_rotated.jpg
#   inflating: train_data/train_set/15114_zoom.jpg
#   inflating: train_data/train_set/15117_h_shifted.jpg
#   inflating: train_data/train_set/15164_noise.jpg
#   inflating: train_data/train_set/15164_h_shifted.jpg
#   inflating: train_data/train_set/15170_noise.jpg
#   inflating: train_data/train_set/15173_original.jpg
#   inflating: train_data/train_set/15191_original.jpg
#   inflating: train_data/train_set/15191_h_shifted.jpg
#   inflating: train_data/train_set/15247_rotated.jpg
#   inflating: train_data/train_set/15262_rotated.jpg
#   inflating: train_data/train_set/15284_zoom.jpg
#   inflating: train_data/train_set/15295_rotated.jpg
#   inflating: train_data/train_set/15303_zoom.jpg
#   inflating: train_data/train_set/15331_rotated.jpg
#   inflating: train_data/train_set/15336_original.jpg
#   inflating: train_data/train_set/15357_v_shifted.jpg
#   inflating: train_data/train_set/15364_rotated.jpg
#   inflating: train_data/train_set/15383_rotated.jpg
#   inflating: train_data/train_set/15387_v_shifted.jpg
#   inflating: train_data/train_set/15390_v_shifted.jpg
#   inflating: train_data/train_set/15391_h_shifted.jpg
#   inflating: train_data/train_set/15410_h_shifted.jpg
#   inflating: train_data/train_set/15424_noise.jpg
#   inflating: train_data/train_set/15438_zoom.jpg
#   inflating: train_data/train_set/15440_v_shifted.jpg
#   inflating: train_data/train_set/15459_h_shifted.jpg
#   inflating: train_data/train_set/15474_original.jpg
#   inflating: train_data/train_set/15476_h_shifted.jpg
#   inflating: train_data/train_set/15486_original.jpg
#   inflating: train_data/train_set/15556_original.jpg
#   inflating: train_data/train_set/15556_rotated.jpg
#   inflating: train_data/train_set/15586_h_shifted.jpg
#   inflating: train_data/train_set/15612_noise.jpg
#   inflating: train_data/train_set/15662_h_shifted.jpg
#   inflating: train_data/train_set/15669_h_shifted.jpg
#   inflating: train_data/train_set/15687_h_shifted.jpg
#   inflating: train_data/train_set/15687_rotated.jpg
#   inflating: train_data/train_set/15688_h_shifted.jpg
#   inflating: train_data/train_set/15694_v_shifted.jpg
#   inflating: train_data/train_set/15721_noise.jpg
#   inflating: train_data/train_set/15732_zoom.jpg
#   inflating: train_data/train_set/15740_original.jpg
#   inflating: train_data/train_set/15751_noise.jpg
#   inflating: train_data/train_set/15753_noise.jpg
#   inflating: train_data/train_set/15757_v_shifted.jpg
#   inflating: train_data/train_set/15786_v_shifted.jpg
#   inflating: train_data/train_set/15788_v_shifted.jpg
#   inflating: train_data/train_set/15824_noise.jpg
#   inflating: train_data/train_set/15837_rotated.jpg
#   inflating: train_data/train_set/15839_h_shifted.jpg
#   inflating: train_data/train_set/15868_zoom.jpg
#   inflating: train_data/train_set/15879_original.jpg
#   inflating: train_data/train_set/15936_v_shifted.jpg
#   inflating: train_data/train_set/15937_v_shifted.jpg
#   inflating: train_data/train_set/15938_h_shifted.jpg
#   inflating: train_data/train_set/15940_v_shifted.jpg
#   inflating: train_data/train_set/15989_v_shifted.jpg

# %% [markdown]
# ## Dataset class

# %%
from PIL import Image

from torch.utils.data import Dataset
from torch.utils.data.sampler import BatchSampler

def get_img_label(img_fp):
    img_fn = img_fp.split('/')[-1]
    img_label = img_fn.split('_')[0]
    return int(img_label)


class FingerprintDataset(Dataset):
    def __init__(self, imgs_fp, transform=None):
        self.imgs_fp = imgs_fp
        self.transform = transform

    def __getitem__(self, idx):
        img_path = self.imgs_fp[idx]
        img = Image.open(img_path).convert('L')
        label = get_img_label(img_path)
        if self.transform is not None:
            img = self.transform(img)
        return img, label

    def __len__(self):
        return len(self.imgs_fp)


class BalancedBatchSampler(BatchSampler):
    """
    BatchSampler - from a MNIST-like dataset, samples n_classes and within these classes samples n_samples.
    Returns batches of size n_classes * n_samples
    """

    def __init__(self, labels, n_classes, n_samples):
        self.labels = labels
        self.labels_set = list(set(self.labels))
        self.label_to_indices = {label: np.where(np.array(self.labels) == label)[0]
                                 for label in self.labels_set}
        for l in self.labels_set:
            np.random.shuffle(self.label_to_indices[l])
        self.used_label_indices_count = {label: 0 for label in self.labels_set}
        self.count = 0
        self.n_classes = n_classes
        self.n_samples = n_samples
        self.n_dataset = len(self.labels)
        self.batch_size = self.n_samples * self.n_classes

    def __iter__(self):
        self.count = 0
        while self.count + self.batch_size < self.n_dataset:
            classes = np.random.choice(self.labels_set, self.n_classes, replace=False)
            indices = []
            for class_ in classes:
                indices.extend(self.label_to_indices[class_][
                               self.used_label_indices_count[class_]:self.used_label_indices_count[
                                                                         class_] + self.n_samples])
                self.used_label_indices_count[class_] += self.n_samples
                if self.used_label_indices_count[class_] + self.n_samples > len(self.label_to_indices[class_]):
                    np.random.shuffle(self.label_to_indices[class_])
                    self.used_label_indices_count[class_] = 0
            yield indices
            self.count += self.n_classes * self.n_samples

    def __len__(self):
        return self.n_dataset // self.batch_size

# %% [markdown]
# ## Network

# %%
import torch.nn as nn


class EmbeddingNet(nn.Module):
    # Input size = (1, 128, 128)
    def __init__(self):
        super(EmbeddingNet, self).__init__()
        self.convnet = nn.Sequential(nn.Conv2d(in_channels=1, out_channels=32, kernel_size=3, stride=1, padding=(1,1)), nn.PReLU(),
                                     nn.MaxPool2d(2, stride=2),
                                     nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, stride=1, padding=(1,1)), nn.PReLU(),
                                     nn.MaxPool2d(2, stride=2),
                                     nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, stride=1, padding=(1,1)), nn.PReLU(),
                                     nn.MaxPool2d(2, stride=2)
                                     )

        self.fc = nn.Sequential(nn.Linear(128 * 16 * 16, 256),
                                nn.PReLU(),
                                nn.Linear(256, 256),
                                nn.PReLU(),
                                nn.Linear(256, 128)
                                )

    def forward(self, x):
        output = self.convnet(x)
        output = output.view(output.size()[0], -1)
        output = self.fc(output)
        return output

    def get_embedding(self, x):
        return self.forward(x)

# %% [markdown]
# ## Loss

# %%
import torch.nn as nn
import torch.nn.functional as F

    
class OnlineTripletLoss(nn.Module):
    """
    Online Triplets loss
    Takes a batch of embeddings and corresponding labels.
    Triplets are generated using triplet_selector object that take embeddings and targets and return indices of
    triplets
    """

    def __init__(self, margin, triplet_selector):
        super(OnlineTripletLoss, self).__init__()
        self.margin = margin
        self.triplet_selector = triplet_selector

    def forward(self, embeddings, target):

        triplets = self.triplet_selector.get_triplets(embeddings, target)

        if embeddings.is_cuda:
            triplets = triplets.cuda()

        ap_distances = (embeddings[triplets[:, 0]] - embeddings[triplets[:, 1]]).pow(2).sum(1)  # .pow(.5)
        an_distances = (embeddings[triplets[:, 0]] - embeddings[triplets[:, 2]]).pow(2).sum(1)  # .pow(.5)
        losses = F.relu(ap_distances - an_distances + self.margin)

        return losses.mean(), len(triplets)

# %%
from itertools import combinations

import numpy as np
import torch


def pdist(vectors):
    distance_matrix = -2 * vectors.mm(torch.t(vectors)) + vectors.pow(2).sum(dim=1).view(1, -1) + vectors.pow(2).sum(
        dim=1).view(-1, 1)
    return distance_matrix


class TripletSelector:
    """
    Implementation should return indices of anchors, positive and negative samples
    return np array of shape [N_triplets x 3]
    """

    def __init__(self):
        pass

    def get_triplets(self, embeddings, labels):
        raise NotImplementedError


def hardest_negative(loss_values):
    hard_negative = np.argmax(loss_values)
    return hard_negative if loss_values[hard_negative] > 0 else None


def semihard_negative(loss_values, margin):
    semihard_negatives = np.where(np.logical_and(loss_values < margin, loss_values > 0))[0]
    return np.random.choice(semihard_negatives) if len(semihard_negatives) > 0 else None


class FunctionNegativeTripletSelector(TripletSelector):
    """
    For each positive pair, takes the hardest negative sample (with the greatest triplet loss value) to create a triplet
    Margin should match the margin used in triplet loss.
    negative_selection_fn should take array of loss_values for a given anchor-positive pair and all negative samples
    and return a negative index for that pair
    """

    def __init__(self, margin, negative_selection_fn, cpu=True):
        super(FunctionNegativeTripletSelector, self).__init__()
        self.cpu = cpu
        self.margin = margin
        self.negative_selection_fn = negative_selection_fn

    def get_triplets(self, embeddings, labels):
        if self.cpu:
            embeddings = embeddings.cpu()
        distance_matrix = pdist(embeddings)
        distance_matrix = distance_matrix.cpu()

        labels = labels.cpu().data.numpy()
        triplets = []

        for label in set(labels):
            label_mask = (labels == label)
            label_indices = np.where(label_mask)[0]
            if len(label_indices) < 2:
                continue
            negative_indices = np.where(np.logical_not(label_mask))[0]
            anchor_positives = list(combinations(label_indices, 2))  # All anchor-positive pairs
            anchor_positives = np.array(anchor_positives)

            ap_distances = distance_matrix[anchor_positives[:, 0], anchor_positives[:, 1]]
            for anchor_positive, ap_distance in zip(anchor_positives, ap_distances):
                loss_values = ap_distance - distance_matrix[torch.LongTensor(np.array([anchor_positive[0]])), torch.LongTensor(negative_indices)] + self.margin
                loss_values = loss_values.data.cpu().numpy()
                hard_negative = self.negative_selection_fn(loss_values)
                if hard_negative is not None:
                    hard_negative = negative_indices[hard_negative]
                    triplets.append([anchor_positive[0], anchor_positive[1], hard_negative])

        if len(triplets) == 0:
            triplets.append([anchor_positive[0], anchor_positive[1], negative_indices[0]])

        triplets = np.array(triplets)

        return torch.LongTensor(triplets)


def HardestNegativeTripletSelector(margin, cpu=False): return FunctionNegativeTripletSelector(margin=margin,
                                                                                 negative_selection_fn=hardest_negative,
                                                                                 cpu=cpu)


def SemihardNegativeTripletSelector(margin, cpu=False): return FunctionNegativeTripletSelector(margin=margin,
                                                                                  negative_selection_fn=lambda x: semihard_negative(x, margin),
                                                                                  cpu=cpu)

# %% [markdown]
# ## Trainer

# %%
import torch
import numpy as np
from tqdm import tqdm

def fit(train_loader, val_loader, model, loss_fn, optimizer, scheduler, n_epochs, cuda, start_epoch=0):
    for epoch in range(0, start_epoch):
        scheduler.step()

    for epoch in range(start_epoch, n_epochs):
        scheduler.step()
        print('Epoch: {}/{}'.format(epoch + 1, n_epochs))

        # Train stage
        train_loss = train_epoch(train_loader, model, loss_fn, optimizer, cuda)

        message = '\nAverage training loss: {:.4f}. '.format(train_loss)

        val_loss = test_epoch(val_loader, model, loss_fn, cuda)
        val_loss /= len(val_loader)

        message += 'Average validating loss: {:.4f}'.format(val_loss)
        print(message)

        torch.save(model.state_dict(), "backup/weight_{}.pth".format(epoch+1), _use_new_zipfile_serialization=False)
        print('Saving model...')

        print('\n' + '='*80 + '\n')

def train_epoch(train_loader, model, loss_fn, optimizer, cuda):
    model.train()
    losses = []
    total_loss = 0

    for batch_idx, (data, target) in enumerate(tqdm(train_loader, desc="Training epoch", position=0, leave=False)):
        target = target if len(target) > 0 else None
        if not type(data) in (tuple, list):
            data = (data,)
        if cuda:
            data = tuple(d.cuda() for d in data)
            if target is not None:
                target = target.cuda()

        optimizer.zero_grad()
        outputs = model(*data)

        if type(outputs) not in (tuple, list):
            outputs = (outputs,)

        loss_inputs = outputs
        if target is not None:
            target = (target,)
            loss_inputs += target

        loss_outputs = loss_fn(*loss_inputs)
        loss = loss_outputs[0] if type(loss_outputs) in (tuple, list) else loss_outputs
        losses.append(loss.item())
        total_loss += loss.item()
        loss.backward()
        optimizer.step()

        losses = []

    total_loss /= (batch_idx + 1)
    return total_loss


def test_epoch(val_loader, model, loss_fn, cuda):
    with torch.no_grad():
        model.eval()
        val_loss = 0
        for batch_idx, (data, target) in enumerate(tqdm(val_loader, desc="Validating epoch", position=0, leave=False)):
            target = target if len(target) > 0 else None
            if not type(data) in (tuple, list):
                data = (data,)
            if cuda:
                data = tuple(d.cuda() for d in data)
                if target is not None:
                    target = target.cuda()

            outputs = model(*data)

            if type(outputs) not in (tuple, list):
                outputs = (outputs,)
            loss_inputs = outputs
            if target is not None:
                target = (target,)
                loss_inputs += target

            loss_outputs = loss_fn(*loss_inputs)
            loss = loss_outputs[0] if type(loss_outputs) in (tuple, list) else loss_outputs
            val_loss += loss.item()

    return val_loss

# %% [markdown]
# ## Train model

# %%
# !rm -rf /content/backup
# !ln -s /content/drive/'My Drive'/fingerprint/backup /content/

# %%
import glob
import torch
import torch.optim as optim
import torch.optim.lr_scheduler as lr_scheduler
from torch.utils.data import DataLoader
import torchvision.transforms as transforms


# Device
cuda = torch.cuda.is_available()
device = torch.device('cuda' if cuda else 'cpu')

# Hyperparameters
in_channel = 1
batch_size = 128
learning_rate = 0.001
step_size = 50
num_epochs = 40


# Load Data
train_dir = sorted(glob.glob('train_data/train_set/*.jpg'))
valid_dir = sorted(glob.glob('train_data/valid_set/*.jpg'))

train_label = [get_img_label(img) for img in train_dir]
valid_label = [get_img_label(img) for img in valid_dir]

# train_classes = list(set(train_label))
# valid_classes = list(set(valid_label))

transforms = transforms.Compose([
    transforms.ToTensor()
])
train_set = FingerprintDataset(train_dir, transforms)
valid_set = FingerprintDataset(valid_dir, transforms)

train_batch_sampler = BalancedBatchSampler(train_label, n_classes=50, n_samples=4)
test_batch_sampler = BalancedBatchSampler(valid_label, n_classes=50, n_samples=4)

# %%
kwargs = {'num_workers': 1, 'pin_memory': True} if cuda else {}

train_loader = DataLoader(dataset=train_set, batch_sampler=train_batch_sampler, **kwargs)
valid_loader = DataLoader(dataset=valid_set, batch_sampler=test_batch_sampler, **kwargs)

# Model
model = EmbeddingNet()

model.to(device)

# Loss and Optimizer
margin = 1.
loss = OnlineTripletLoss(margin, HardestNegativeTripletSelector(margin))
optimizer = optim.Adam(filter(lambda p: p.requires_grad, model.parameters()), lr=learning_rate)
scheduler = lr_scheduler.StepLR(optimizer, step_size=step_size, gamma=0.1)

# %%
# Train Network
fit(train_loader, valid_loader, model, loss, optimizer, scheduler, num_epochs, cuda)
# Out:
# Training epoch:   0%|          | 0/480 [00:00<?, ?it/s]
# Epoch: 1/40
# Training epoch:   0%|          | 0/480 [00:00<?, ?it/s]
# Average training loss: 1.4202. Average validating loss: 0.5042
# Saving model...
#
# ================================================================================
#
# Epoch: 2/40
# Training epoch:   0%|          | 0/480 [00:00<?, ?it/s]
# Average training loss: 1.2216. Average validating loss: 0.7267
# Saving model...
#
# ================================================================================
#
# Epoch: 3/40
# Training epoch:   0%|          | 0/480 [00:00<?, ?it/s]
# Average training loss: 1.0227. Average validating loss: 1.4945
# Saving model...
#
# ================================================================================
#
# Epoch: 4/40
# Training epoch:   0%|          | 0/480 [00:00<?, ?it/s]
# Average training loss: 1.0831. Average validating loss: 0.9568
# Saving model...
#
# ================================================================================
#
# Epoch: 5/40
# Training epoch:   0%|          | 0/480 [00:00<?, ?it/s]
# Average training loss: 1.0606. Average validating loss: 0.9250
# Saving model...
#
# ================================================================================
#
# Epoch: 6/40
# Training epoch:   0%|          | 0/480 [00:00<?, ?it/s]
# Average training loss: 0.9334. Average validating loss: 0.7243
# Saving model...
#
# ================================================================================
#
# Epoch: 7/40
# Training epoch:   0%|          | 0/480 [00:00<?, ?it/s]
# Average training loss: 0.9294. Average validating loss: 0.8271
# Saving model...
#
# ================================================================================
#
# Epoch: 8/40
# Training epoch:   0%|          | 0/480 [00:00<?, ?it/s]
# Average training loss: 0.8835. Average validating loss: 0.8942
# Saving model...
#
# ================================================================================
#
# Epoch: 9/40
# Training epoch:   0%|          | 0/480 [00:00<?, ?it/s]
# Average training loss: 0.8806. Average validating loss: 0.5526
# Saving model...
#
# ================================================================================
#
# Epoch: 10/40
# Training epoch:   0%|          | 0/480 [00:00<?, ?it/s]
# Average training loss: 0.8326. Average validating loss: 1.0035
# Saving model...
#
# ================================================================================
#
# Epoch: 11/40
# Training epoch:   0%|          | 0/480 [00:00<?, ?it/s]
# Average training loss: 1.0813. Average validating loss: 1.0225
# Saving model...
#
# ================================================================================
#
# Epoch: 12/40
# Training epoch:   0%|          | 0/480 [00:00<?, ?it/s]
# Average training loss: 0.8353. Average validating loss: 1.0768
# Saving model...
#
# ================================================================================
#
# Epoch: 13/40
# Training epoch:   0%|          | 0/480 [00:00<?, ?it/s]
# Average training loss: 0.8314. Average validating loss: 1.4147
# Saving model...
#
# ================================================================================
#
# Epoch: 14/40
# Training epoch:   0%|          | 0/480 [00:00<?, ?it/s]
# Average training loss: 1.0814. Average validating loss: 0.8484
# Saving model...
#
# ================================================================================
#
# Epoch: 15/40
# Training epoch:   0%|          | 0/480 [00:00<?, ?it/s]
# Average training loss: 1.3139. Average validating loss: 0.9360
# Saving model...
#
# ================================================================================
#
# Epoch: 16/40
# Training epoch:   0%|          | 0/480 [00:00<?, ?it/s]
# Average training loss: 1.0279. Average validating loss: 1.2267
# Saving model...
#
# ================================================================================
#
# Epoch: 17/40
# Training epoch:   0%|          | 0/480 [00:00<?, ?it/s]
# Average training loss: 0.9849. Average validating loss: 0.9871
# Saving model...
#
# ================================================================================
#
# Epoch: 18/40
# Training epoch:   0%|          | 0/480 [00:00<?, ?it/s]
# Average training loss: 1.2127. Average validating loss: 1.3147
# Saving model...
#
# ================================================================================
#
# Epoch: 19/40
# Training epoch:   0%|          | 0/480 [00:00<?, ?it/s]
# Average training loss: 0.8601. Average validating loss: 0.9633
# Saving model...
#
# ================================================================================
#
# Epoch: 20/40
# Training epoch:   0%|          | 0/480 [00:00<?, ?it/s]
# Average training loss: 0.8849. Average validating loss: 0.8959
# Saving model...
#
# ================================================================================
#
# Epoch: 21/40
# Training epoch:   0%|          | 0/480 [00:00<?, ?it/s]
# Average training loss: 0.9806. Average validating loss: 0.8241
# Saving model...
#
# ================================================================================
#
# Epoch: 22/40
# Training epoch:   0%|          | 0/480 [00:00<?, ?it/s]
# Average training loss: 0.8265. Average validating loss: 1.5178
# Saving model...
#
# ================================================================================
#
# Epoch: 23/40
# Training epoch:   0%|          | 0/480 [00:00<?, ?it/s]
# Average training loss: 0.9056. Average validating loss: 0.9116
# Saving model...
#
# ================================================================================
#
# Epoch: 24/40
# Training epoch:   0%|          | 0/480 [00:00<?, ?it/s]
# Average training loss: 0.7605. Average validating loss: 0.9464
# Saving model...
#
# ================================================================================
#
# Epoch: 25/40
# Training epoch:   0%|          | 0/480 [00:00<?, ?it/s]
# Average training loss: 3.2244. Average validating loss: 1.1860
# Saving model...
#
# ================================================================================
#
# Epoch: 26/40
# Training epoch:   0%|          | 0/480 [00:00<?, ?it/s]
# Average training loss: 0.8840. Average validating loss: 0.8141
# Saving model...
#
# ================================================================================
#
# Epoch: 27/40
# Training epoch:   0%|          | 0/480 [00:00<?, ?it/s]
# Average training loss: 0.9804. Average validating loss: 1.0684
# Saving model...
#
# ================================================================================
#
# Epoch: 28/40
# Training epoch:   0%|          | 0/480 [00:00<?, ?it/s]
# Average training loss: 0.7836. Average validating loss: 0.9213
# Saving model...
#
# ================================================================================
#
# Epoch: 29/40
# Training epoch:   0%|          | 0/480 [00:00<?, ?it/s]
# Average training loss: 0.8966. Average validating loss: 1.0844
# Saving model...
#
# ================================================================================
#
# Epoch: 30/40
# Training epoch:   0%|          | 0/480 [00:00<?, ?it/s]
# Average training loss: 0.6522. Average validating loss: 0.8896
# Saving model...
#
# ================================================================================
#
# Epoch: 31/40
# Training epoch:   0%|          | 0/480 [00:00<?, ?it/s]
# Average training loss: 2.4527. Average validating loss: 1.3486
# Saving model...
#
# ================================================================================
#
# Epoch: 32/40
# Training epoch:   0%|          | 0/480 [00:00<?, ?it/s]
# Average training loss: 0.7136. Average validating loss: 0.8822
# Saving model...
#
# ================================================================================
#
# Epoch: 33/40
# Training epoch:   0%|          | 0/480 [00:00<?, ?it/s]
# Average training loss: 0.8006. Average validating loss: 1.0084
# Saving model...
#
# ================================================================================
#
# Epoch: 34/40
# Training epoch:   0%|          | 0/480 [00:00<?, ?it/s]
# Average training loss: 0.6515. Average validating loss: 0.7762
# Saving model...
#
# ================================================================================
#
# Epoch: 35/40
# Training epoch:   0%|          | 0/480 [00:00<?, ?it/s]
# Average training loss: 0.6023. Average validating loss: 0.4460
# Saving model...
#
# ================================================================================
#
# Epoch: 36/40
# Training epoch:   0%|          | 0/480 [00:00<?, ?it/s]
# Average training loss: 0.5724. Average validating loss: 0.6049
# Saving model...
#
# ================================================================================
#
# Epoch: 37/40
# Training epoch:   0%|          | 0/480 [00:00<?, ?it/s]
# Average training loss: 1.0373. Average validating loss: 2.7965
# Saving model...
#
# ================================================================================
#
# Epoch: 38/40
# Training epoch:   0%|          | 0/480 [00:00<?, ?it/s]
# Average training loss: 0.5836. Average validating loss: 0.2088
# Saving model...
#
# ================================================================================
#
# Epoch: 39/40
# Training epoch:   0%|          | 0/480 [00:00<?, ?it/s]
# Average training loss: 0.4052. Average validating loss: 0.1475
# Saving model...
#
# ================================================================================
#
# Epoch: 40/40
# Average training loss: 0.8527. Average validating loss: 0.3525
# Saving model...
#
# ================================================================================
